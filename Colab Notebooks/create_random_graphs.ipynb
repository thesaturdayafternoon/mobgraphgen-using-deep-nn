# %% [markdown]
# # **Create Random Graphs**
#
# This code generates uniformly random graphs and saves them.

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# %cd drive/MyDrive/mobgraphgen
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/mobgraphgen
# args.py			    eval	     main.py	   tarscript.sh
# baselines		    evaluate.py      map_info.py   tensorboard
# bin			    figures	     maps_info.py  tmp
# build_real_mob_graph.py     fs_tag_tree.txt  metrics	   train.py
# build.sh		    graphgen	     model.py	   untarscript.sh
# create_graphs_gradually.py  graphs	     model_save    util_priv_eval
# datasets		    input_london1    new_tree.py   utils.py
# dfscode			    input_london2    __pycache__
# edens			    input_london3    README.md

# %%
# !pip install haversine
# !pip install networkx
# !pip install dgl
# !pip install dill
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 17.3 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 3.2 MB/s eta 0:00:00
# ...

# %%
from build_real_mob_graph import create_random_uniform_graphs,print_graph_lengths_info
from build_real_mob_graph import plot_labeled_graph,convert_graph_to_lists,plot_graph,print_nodes_info,print_edges_info
from build_real_mob_graph import save_graphs_for_any_dir
from args import Args
import os

# %%
args=Args()
args=args.update_args()
base_path = os.path.join(args.dataset_path, 'grid/')
graph_samples_path=os.path.join(base_path, 'graph_samples/')

# %%
random_graphs=create_random_uniform_graphs(args.city_names,args.chunk_size,args.second_sample_desired_size,graph_samples_path,change_indexes="")

# %%
print_graph_lengths_info(random_graphs,graph_type="grid")
# Out:
# number of graphs =  2000
# lengths information:
# 10 :  2000

# %%
save_graphs_for_any_dir(graph_samples_path,"random_sample_graphs",random_graphs)
